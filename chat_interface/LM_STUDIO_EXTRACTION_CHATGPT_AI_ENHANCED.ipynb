# %%
# !pip install tiktoken pypdf aiohttp aiofiles
# Out:
# Requirement already satisfied: tiktoken in /home/ssa/Workspace/final_project_qna/venv/lib/python3.10/site-packages (0.12.0)
# Requirement already satisfied: pypdf in /home/ssa/Workspace/final_project_qna/venv/lib/python3.10/site-packages (6.1.3)
# Requirement already satisfied: aiohttp in /home/ssa/Workspace/final_project_qna/venv/lib/python3.10/site-packages (3.13.2)
# Requirement already satisfied: aiofiles in /home/ssa/Workspace/final_project_qna/venv/lib/python3.10/site-packages (25.1.0)
# Requirement already satisfied: regex>=2022.1.18 in /home/ssa/Workspace/final_project_qna/venv/lib/python3.10/site-packages (from tiktoken) (2025.10.23)
# Requirement already satisfied: requests>=2.26.0 in /home/ssa/Workspace/final_project_qna/venv/lib/python3.10/site-packages (from tiktoken) (2.32.5)
# Requirement already satisfied: typing_extensions>=4.0 in /home/ssa/Workspace/final_project_qna/venv/lib/python3.10/site-packages (from pypdf) (4.15.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /home/ssa/Workspace/final_project_qna/venv/lib/python3.10/site-packages (from aiohttp) (2.6.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/ssa/Workspace/final_project_qna/venv/lib/python3.10/site-packages (from aiohttp) (1.8.0)
# Requirement already satisfied: aiosignal>=1.4.0 in /home/ssa/Workspace/final_project_qna/venv/lib/python3.10/site-packages (from aiohttp) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /home/ssa/Workspace/final_project_qna/venv/lib/python3.10/site-packages (from aiohttp) (25.4.0)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /home/ssa/Workspace/final_project_qna/venv/lib/python3.10/site-packages (from aiohttp) (5.0.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/ssa/Workspace/final_project_qna/venv/lib/python3.10/site-packages (from aiohttp) (6.7.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/ssa/Workspace/final_project_qna/venv/lib/python3.10/site-packages (from aiohttp) (1.22.0)
# Requirement already satisfied: propcache>=0.2.0 in /home/ssa/Workspace/final_project_qna/venv/lib/python3.10/site-packages (from aiohttp) (0.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/ssa/Workspace/final_project_qna/venv/lib/python3.10/site-packages (from requests>=2.26.0->tiktoken) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/ssa/Workspace/final_project_qna/venv/lib/python3.10/site-packages (from requests>=2.26.0->tiktoken) (2.5.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/ssa/Workspace/final_project_qna/venv/lib/python3.10/site-packages (from requests>=2.26.0->tiktoken) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ssa/Workspace/final_project_qna/venv/lib/python3.10/site-packages (from requests>=2.26.0->tiktoken) (2025.10.5)

# %%
#!/usr/bin/env python3
import os
import tempfile
import asyncio
from pathlib import Path
from typing import List, Tuple
from dataclasses import dataclass
import aiohttp
import json
import random
from enum import Enum
import re # Added for post-processing

try:
    from pypdf import PdfReader, PdfWriter  # pip install pypdf
except ImportError:
    raise SystemExit("Please: pip install pypdf")

try:
    import aiofiles  # pip install aiofiles
except ImportError:
    raise SystemExit("Please: pip install aiofiles")

# ---------------- CONFIG ----------------
class ModelConfig(Enum):
    # Put your LM Studio model ID here (e.g., "qwen2.5-7b-instruct", "llama-3.1-8b-instruct", etc.)
    LOCAL_DEFAULT = "qwen/qwen3-coder-30b"

MODEL = ModelConfig.LOCAL_DEFAULT.value
FOLDER_PATH = "pdfs_20_2"             # Folder containing PDFs
# Simplified and more robust output directory naming
OUTPUT_DIR = f"lmstudio_output_md/chat-gpt/{MODEL.replace('/', '_')}"
PAGES_PER_CHUNK = 2               # Adjust chunk size as needed
TEMPERATURE = 0.0
MAX_CONCURRENT = 2

# LM Studio local server (OpenAI-compatible)
LMSTUDIO_BASE_URL = os.getenv("LMSTUDIO_BASE_URL", "http://192.168.10.60:12345/v1")
LMSTUDIO_API_KEY = os.getenv("LMSTUDIO_API_KEY", "")

# Token/accounting knobs
CONTEXT_WINDOW_TOKENS = int(os.getenv("CTX_TOKENS", "8192"))   # adjust to your model’s context
MAX_OUTPUT_TOKENS     = int(os.getenv("MAX_OUTPUT_TOKENS", "2048")) # Increased for more detailed output
TOKEN_SAFETY_MARGIN   = int(os.getenv("TOKEN_SAFETY_MARGIN", "200"))  # guard for system/meta tokens

# To avoid blowing context windows; coarse char clamp (still useful even with token counting)
MAX_CHARS_PER_REQUEST = 15000

# --- NEW: Configuration for output ---
# Set to True to include token usage info in the final .md file (useful for debugging)
# Set to False for clean, production-ready markdown files.
INCLUDE_TOKEN_INFO_IN_OUTPUT = False
# ----------------------------------------


@dataclass
class ChunkInfo:
    pdf_name: str
    chunk_index: int
    chunk_path: str
    page_range_label: str


class TokenCounter:
    """
    Prefers tiktoken (accurate, fast). If unavailable, uses a chars→tokens heuristic (~4 chars/token).
    """
    def __init__(self):
        self._enc = None
        self._mode = "heuristic"
        try:
            import tiktoken  # type: ignore
            # cl100k_base works well for most chat models; it’s close enough for counting budget
            self._enc = tiktoken.get_encoding("cl100k_base")
            self._mode = "tiktoken:cl100k_base"
        except Exception:
            self._enc = None

    def count(self, text: str) -> int:
        if not text:
            return 0
        if self._enc:
            try:
                return len(self._enc.encode(text))
            except Exception:
                pass
        # Heuristic fallback: 4 chars ≈ 1 token (conservative)
        return max(1, len(text) // 4)

    def __repr__(self) -> str:
        return f"<TokenCounter mode={self._mode}>"


class AsyncPDFProcessor:
    def __init__(self, base_url: str, api_key: str = ""):
        self.base_url = base_url.rstrip("/")
        self.api_key = api_key or None
        self.tok = TokenCounter()

    # ---------- FS & splitting ----------

    def get_pdf_files(self, folder_path: str) -> List[Path]:
        folder = Path(folder_path)
        if not folder.exists():
            raise SystemExit(f"Folder {folder_path} does not exist.")
        pdf_files = list(folder.glob("*.pdf"))
        if not pdf_files:
            raise SystemExit(f"No PDF files found in {folder_path}")
        return pdf_files

    def split_pdf_to_chunks(self, pdf_path: str, pages_per_chunk: int) -> List[ChunkInfo]:
        reader = PdfReader(pdf_path)
        n_pages = len(reader.pages)
        chunks: List[ChunkInfo] = []
        pdf_name = Path(pdf_path).stem

        for chunk_idx, start in enumerate(range(0, n_pages, pages_per_chunk)):
            end = min(start + pages_per_chunk, n_pages)
            writer = PdfWriter()
            for i in range(start, end):
                writer.add_page(reader.pages[i])

            fd, tmp_pdf = tempfile.mkstemp(
                suffix=f".{pdf_name}.chunk{chunk_idx:03d}.{start+1}-{end}.pdf"
            )
            os.close(fd)
            with open(tmp_pdf, "wb") as f:
                writer.write(f)

            page_range_label = f"pages {start+1}–{end}"
            chunks.append(ChunkInfo(
                pdf_name=pdf_name,
                chunk_index=chunk_idx,
                chunk_path=tmp_pdf,
                page_range_label=page_range_label
            ))
        return chunks

    # ---------- helpers ----------

    def extract_text_from_pdf(self, pdf_path: str) -> str:
        try:
            reader = PdfReader(pdf_path)
            parts = []
            for i, page in enumerate(reader.pages, start=1):
                try:
                    txt = page.extract_text() or ""
                except Exception:
                    txt = ""
                if txt.strip():
                    parts.append(f"\n\n[Page {i}]\n{txt.strip()}")
                else:
                    parts.append(f"\n\n[Page {i}]")
            return "".join(parts)
        except Exception as e:
            return f"[EXTRACTION_ERROR] {e}"

    def clamp(self, s: str, max_chars: int) -> str:
        return s if len(s) <= max_chars else s[:max_chars]

    # --- NEW: Document Type Detection ---
    def detect_document_type(self, text: str) -> str:
        """Detect if document is academic, technical, legal, or general."""
        text_lower = text.lower()
        if any(word in text_lower for word in ["abstract", "introduction", "methodology", "results", "conclusion", "bibliography", "references"]):
            return "academic"
        elif any(word in text_lower for word in ["specification", "requirements", "api", "technical", "manual", "implementation"]):
            return "technical"
        elif any(word in text_lower for word in ["contract", "agreement", "terms", "legal", "clause", "party", "liability"]):
            return "legal"
        return "general"

    # --- NEW: Dynamic Prompt Selection ---
    def get_dynamic_prompt(self, doc_type: str) -> str:
        """Returns a specialized prompt based on the document type."""
        base_prompt = (
            "You are an expert document processor converting PDFs to clean, structured Markdown for a RAG knowledge base. "
            "Your goal is to preserve all semantic information while improving readability and searchability.\n\n"

            "STRUCTURE PRESERVATION:\n"
            "1) Create a logical heading hierarchy using # (main title), ## (sections), ### (subsections), etc.\n"
            "2) Preserve document outline and section numbering when present.\n"
            "3) Maintain paragraph breaks and indentation where meaningful.\n\n"

            "CONTENT FORMATTING:\n"
            "4) Convert tables to proper Markdown format with aligned columns.\n"
            "5) Preserve list structures (ordered and unordered) with proper indentation.\n"
            "6) Maintain text formatting: **bold**, *italic*, `code`, etc.\n"
            "7) Convert URLs to clickable Markdown links: [text](url).\n\n"

            "SPECIAL ELEMENTS:\n"
            "8) For mathematical formulas, use LaTeX notation: $inline$ or $$block$$.\n"
            "9) Represent images as: ![Image description](image_reference) with descriptive alt text.\n"
            "10) For charts/graphs, include a brief description of what they visualize.\n\n"

            "CLEANUP:\n"
            "11) Remove repeated headers/footers, page numbers (except where meaningful), and watermarks.\n"
            "12) Fix OCR errors and typos when obvious, but preserve technical terms.\n"
            "13) Merge hyphenated words at line breaks.\n\n"

            "IMPORTANT:\n"
            "14) Output ONLY valid Markdown with no explanations or commentary.\n"
            "15) Preserve all substantive content - do not summarize or omit sections.\n"
            "16) When uncertain about formatting, prioritize preserving content over perfect structure."
        )

        if doc_type == "academic":
            return base_prompt + "\n17) Preserve citations, references, and bibliographic formatting exactly as they appear."
        elif doc_type == "technical":
            return base_prompt + "\n17) Preserve code blocks, technical diagrams, and API specifications with high fidelity."
        elif doc_type == "legal":
            return base_prompt + "\n17) Preserve legal numbering, clauses, definitions, and signature blocks exactly."

        return base_prompt

    # --- NEW: Markdown Post-Processing ---
    def post_process_markdown(self, md_text: str) -> str:
        """Cleans up common issues in the generated Markdown."""
        # Normalize multiple newlines to a maximum of two
        md_text = re.sub(r'\n{3,}', '\n\n', md_text)
        # Ensure the file ends with a single newline
        if not md_text.endswith('\n'):
            md_text += '\n'
        return md_text.strip()

    async def _with_retries(self, coro_factory, *, tries=5, base=0.7, max_sleep=10.0):
        last = None
        for i in range(tries):
            try:
                return await coro_factory()
            except Exception as e:
                last = e
                msg = str(e).lower()
                retryable = any(s in msg for s in ("429", "timeout", "temporarily", "5", "rate", "connection", "reset", "refused"))
                if retryable and i < tries - 1:
                    sleep_for = min(max_sleep, base * (2 ** i)) + random.random()
                    await asyncio.sleep(sleep_for)
                else:
                    break
        raise last

    # ---------- LM Studio chat/completions ----------

    async def chat_markdownify(self, session: aiohttp.ClientSession, model: str, system_prompt: str, user_text: str, temperature: float, max_tokens: int) -> str:
        headers = {"Content-Type": "application/json"}
        if self.api_key:
            headers["Authorization"] = f"Bearer {self.api_key}"

        payload = {
            "model": model,
            "messages": [
                {"role": "system", "content": system_prompt},
                {"role": "user", "content": user_text},
            ],
            "temperature": temperature,
            "max_tokens": max_tokens,
            "stream": False
        }
        url = f"{self.base_url}/chat/completions"
        async with session.post(url, json=payload, headers=headers) as r:
            if r.status != 200:
                t = await r.text()
                raise Exception(f"LM Studio API error {r.status}: {t}")
            data = await r.json()
            return data["choices"][0]["message"]["content"].strip()

    # ---------- per-chunk pipeline ----------

    async def process_one_chunk(
        self,
        session: aiohttp.ClientSession,
        semaphore: asyncio.Semaphore,
        chunk: ChunkInfo
    ) -> Tuple[int, str]:
        async with semaphore:
            try:
                raw_text = self.extract_text_from_pdf(chunk.chunk_path)
                clamped = self.clamp(raw_text, MAX_CHARS_PER_REQUEST)

                # --- ENHANCED PROMPT LOGIC ---
                doc_type = self.detect_document_type(clamped)
                system_prompt = self.get_dynamic_prompt(doc_type)

                user_prompt = (
                    f"Convert this extracted PDF chunk ({chunk.page_range_label}) to Markdown.\n\n"
                    f"--- BEGIN EXTRACTED TEXT ---\n{clamped}\n--- END EXTRACTED TEXT ---"
                )

                # ---- token counting ----
                sys_toks = self.tok.count(system_prompt)
                usr_toks = self.tok.count(user_prompt)
                in_toks  = sys_toks + usr_toks

                # Budget for output within the context window
                available = max(256, CONTEXT_WINDOW_TOKENS - in_toks - TOKEN_SAFETY_MARGIN)
                max_out = max(64, min(MAX_OUTPUT_TOKENS, available))

                print(
                    f"🔢 {chunk.pdf_name} | {chunk.page_range_label} | "
                    f"type: {doc_type} | "
                    f"tokens: in={in_toks} (sys={sys_toks}, user={usr_toks}) | "
                    f"max_out={max_out} | ctx={CONTEXT_WINDOW_TOKENS} | {self.tok}"
                )

                md = await self._with_retries(
                    lambda: self.chat_markdownify(
                        session,
                        MODEL,
                        system_prompt,
                        user_prompt,
                        temperature=TEMPERATURE,
                        max_tokens=int(max_out)
                    )
                )

                # --- POST-PROCESSING ---
                md = self.post_process_markdown(md)

                # --- CONDITIONAL OUTPUT FORMATTING ---
                if INCLUDE_TOKEN_INFO_IN_OUTPUT:
                    header = (
                        f"\n\n---\n*Chunk {chunk.page_range_label}*\n"
                        f"*Document Type:* {doc_type}\n"
                        f"*Token usage:* input={in_toks} (sys={sys_toks}, user={usr_toks}), max_out={max_out}, ctx={CONTEXT_WINDOW_TOKENS}\n"
                        f"---\n\n"
                    )
                    formatted = f"{header}{md}"
                else:
                    formatted = md

                print(f"✅ {chunk.pdf_name} | {chunk.page_range_label}")
                return chunk.chunk_index, formatted
            except Exception as e:
                print(f"⚠️ {chunk.pdf_name} | {chunk.page_range_label} failed: {e}")
                error_msg = f"\n\n---\n*Error processing {chunk.page_range_label}: {e}*\n---\n\n"
                return chunk.chunk_index, error_msg
            finally:
                try:
                    os.remove(chunk.chunk_path)
                except OSError:
                    pass

    async def process_single_pdf(self, session: aiohttp.ClientSession, pdf_path: str, output_dir: str):
        pdf_name = Path(pdf_path).stem
        print(f"\n📄 Processing PDF: {Path(pdf_path).name}")
        chunks = self.split_pdf_to_chunks(pdf_path, PAGES_PER_CHUNK)
        print(f"🔧 Split into {len(chunks)} chunks (window={MAX_CONCURRENT})")

        semaphore = asyncio.Semaphore(MAX_CONCURRENT)
        tasks = [asyncio.create_task(self.process_one_chunk(session, semaphore, ch)) for ch in chunks]
        results: List[Tuple[int, str]] = await asyncio.gather(*tasks)

        results.sort(key=lambda x: x[0])
        merged_md = "".join(md for _, md in results).strip() + "\n"

        os.makedirs(output_dir, exist_ok=True)
        out_path = os.path.join(output_dir, f"{pdf_name}.md")
        async with aiofiles.open(out_path, "w", encoding="utf-8") as f:
            await f.write(merged_md)
        print(f"✅ Wrote {out_path}")

    async def process_folder_sequential(self, folder_path: str, output_dir: str):
        print(f"🔍 Scanning: {folder_path}")
        pdf_files = self.get_pdf_files(folder_path)
        print(f"📚 Found {len(pdf_files)} PDFs")

        connector = aiohttp.TCPConnector(
            limit=MAX_CONCURRENT * 1,
            limit_per_host=MAX_CONCURRENT,
            ttl_dns_cache=300,
            use_dns_cache=True,
        )
        timeout = aiohttp.ClientTimeout(total=9000)

        async with aiohttp.ClientSession(connector=connector, timeout=timeout) as session:
            for idx, pdf in enumerate(pdf_files, 1):
                print(f"\n🚀 [{idx}/{len(pdf_files)}] Start {Path(pdf).name}")
                await self.process_single_pdf(session, pdf, output_dir)
                print(f"🏁 [{idx}/{len(pdf_files)}] Done {Path(pdf).name}")


async def main_async():
    processor = AsyncPDFProcessor(LMSTUDIO_BASE_URL, api_key=LMSTUDIO_API_KEY or "")
    await processor.process_folder_sequential(FOLDER_PATH, OUTPUT_DIR)


if __name__ == "__main__":
    await main_async()
# Out:
# 🔍 Scanning: pdfs_20_2
# 📚 Found 273 PDFs
#
# 🚀 [1/273] Start 37_gcf-b39-02-add14-funding-proposal-package-fp239.pdf
#
# 📄 Processing PDF: 37_gcf-b39-02-add14-funding-proposal-package-fp239.pdf
# 🔧 Split into 122 chunks (window=2)
# 🔢 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 1–2 | type: technical | tokens: in=641 (sys=315, user=326) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# 🔢 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 3–4 | type: general | tokens: in=799 (sys=299, user=500) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ✅ 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 1–2
# 🔢 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 5–6 | type: legal | tokens: in=1356 (sys=314, user=1042) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ✅ 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 3–4
# 🔢 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 7–8 | type: academic | tokens: in=867 (sys=315, user=552) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 5–6 failed:
# 🔢 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 9–10 | type: academic | tokens: in=2091 (sys=315, user=1776) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 7–8 failed:
# 🔢 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 11–12 | type: technical | tokens: in=2406 (sys=315, user=2091) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 9–10 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 13–14 | type: academic | tokens: in=1393 (sys=315, user=1078) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 11–12 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 15–16 | type: general | tokens: in=1630 (sys=299, user=1331) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 13–14 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 17–18 | type: technical | tokens: in=2480 (sys=315, user=2165) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 17–18 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 19–20 | type: legal | tokens: in=2429 (sys=314, user=2115) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 15–16 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 21–22 | type: legal | tokens: in=1791 (sys=314, user=1477) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 19–20 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 23–24 | type: academic | tokens: in=1691 (sys=315, user=1376) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 21–22 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 25–26 | type: technical | tokens: in=1520 (sys=315, user=1205) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 23–24 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 27–28 | type: technical | tokens: in=1537 (sys=315, user=1222) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 27–28 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 29–30 | type: academic | tokens: in=1840 (sys=315, user=1525) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 25–26 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 31–32 | type: technical | tokens: in=2634 (sys=315, user=2319) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 29–30 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 33–34 | type: technical | tokens: in=2027 (sys=315, user=1712) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 31–32 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 35–36 | type: technical | tokens: in=1811 (sys=315, user=1496) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 35–36 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 37–38 | type: academic | tokens: in=2313 (sys=315, user=1998) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 33–34 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 39–40 | type: academic | tokens: in=2305 (sys=315, user=1990) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 37–38 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 41–42 | type: academic | tokens: in=2433 (sys=315, user=2118) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 39–40 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 43–44 | type: academic | tokens: in=2524 (sys=315, user=2209) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 43–44 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 45–46 | type: technical | tokens: in=2490 (sys=315, user=2175) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 41–42 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 47–48 | type: academic | tokens: in=1599 (sys=315, user=1284) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 47–48 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 49–50 | type: academic | tokens: in=2314 (sys=315, user=1999) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 45–46 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 51–52 | type: technical | tokens: in=2264 (sys=315, user=1949) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 49–50 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 53–54 | type: technical | tokens: in=2380 (sys=315, user=2065) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 53–54 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 55–56 | type: academic | tokens: in=2224 (sys=315, user=1909) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 51–52 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 57–58 | type: technical | tokens: in=2098 (sys=315, user=1783) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 55–56 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 59–60 | type: academic | tokens: in=2609 (sys=315, user=2294) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 57–58 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 61–62 | type: technical | tokens: in=2225 (sys=315, user=1910) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 61–62 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 63–64 | type: technical | tokens: in=2546 (sys=315, user=2231) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 63–64 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 65–66 | type: academic | tokens: in=1742 (sys=315, user=1427) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 65–66 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 67–68 | type: general | tokens: in=1297 (sys=299, user=998) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 59–60 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 69–70 | type: academic | tokens: in=2354 (sys=315, user=2039) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 69–70 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 71–72 | type: academic | tokens: in=2372 (sys=315, user=2057) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 71–72 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 73–74 | type: technical | tokens: in=2356 (sys=315, user=2041) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 73–74 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 75–76 | type: technical | tokens: in=2153 (sys=315, user=1838) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 75–76 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 77–78 | type: academic | tokens: in=2474 (sys=315, user=2159) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 77–78 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 79–80 | type: academic | tokens: in=1395 (sys=315, user=1080) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 79–80 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 81–82 | type: academic | tokens: in=1752 (sys=315, user=1437) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 67–68 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 83–84 | type: academic | tokens: in=1408 (sys=315, user=1093) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 81–82 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 85–86 | type: academic | tokens: in=1470 (sys=315, user=1155) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 83–84 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 87–88 | type: academic | tokens: in=1578 (sys=315, user=1263) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 87–88 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 89–90 | type: academic | tokens: in=1331 (sys=315, user=1016) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 85–86 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 91–92 | type: academic | tokens: in=1263 (sys=315, user=948) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 89–90 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 93–94 | type: technical | tokens: in=1152 (sys=315, user=837) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 91–92 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 95–96 | type: academic | tokens: in=1328 (sys=315, user=1013) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 93–94 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 97–98 | type: academic | tokens: in=1543 (sys=315, user=1228) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 95–96 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 99–100 | type: academic | tokens: in=1236 (sys=315, user=921) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 99–100 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 101–102 | type: academic | tokens: in=1360 (sys=315, user=1045) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 97–98 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 103–104 | type: technical | tokens: in=2009 (sys=315, user=1694) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 101–102 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 105–106 | type: technical | tokens: in=994 (sys=315, user=679) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 103–104 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 107–108 | type: technical | tokens: in=1813 (sys=315, user=1498) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 105–106 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 109–110 | type: academic | tokens: in=2093 (sys=315, user=1778) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 107–108 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 111–112 | type: technical | tokens: in=2142 (sys=315, user=1827) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 109–110 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 113–114 | type: academic | tokens: in=2106 (sys=315, user=1791) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 113–114 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 115–116 | type: technical | tokens: in=1166 (sys=315, user=851) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 115–116 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 117–118 | type: general | tokens: in=610 (sys=299, user=311) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 117–118 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 119–120 | type: general | tokens: in=436 (sys=299, user=137) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 119–120 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 121–122 | type: general | tokens: in=544 (sys=299, user=245) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 121–122 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 123–124 | type: technical | tokens: in=1337 (sys=315, user=1022) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 123–124 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 125–126 | type: technical | tokens: in=1587 (sys=315, user=1272) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 111–112 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 127–128 | type: academic | tokens: in=2213 (sys=315, user=1898) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 127–128 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 129–130 | type: technical | tokens: in=2320 (sys=315, user=2005) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 129–130 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 131–132 | type: technical | tokens: in=1633 (sys=315, user=1318) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 125–126 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 133–134 | type: technical | tokens: in=1618 (sys=315, user=1303) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 133–134 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 135–136 | type: general | tokens: in=931 (sys=299, user=632) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 131–132 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 137–138 | type: general | tokens: in=959 (sys=299, user=660) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 137–138 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 139–140 | type: general | tokens: in=339 (sys=299, user=40) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 135–136 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 141–142 | type: general | tokens: in=1201 (sys=299, user=902) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 141–142 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 143–144 | type: technical | tokens: in=1254 (sys=315, user=939) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 143–144 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 145–146 | type: technical | tokens: in=1129 (sys=315, user=814) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 145–146 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 147–148 | type: technical | tokens: in=1819 (sys=315, user=1504) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 147–148 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 149–150 | type: technical | tokens: in=1761 (sys=315, user=1446) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 139–140 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 151–152 | type: academic | tokens: in=1875 (sys=315, user=1560) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 149–150 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 153–154 | type: academic | tokens: in=1860 (sys=315, user=1545) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 151–152 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 155–156 | type: academic | tokens: in=2070 (sys=315, user=1755) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 153–154 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 157–158 | type: technical | tokens: in=1862 (sys=315, user=1547) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 155–156 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 159–160 | type: technical | tokens: in=1790 (sys=315, user=1475) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 159–160 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 161–162 | type: academic | tokens: in=1617 (sys=315, user=1302) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 161–162 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 163–164 | type: academic | tokens: in=1925 (sys=315, user=1610) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 163–164 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 165–166 | type: academic | tokens: in=2043 (sys=315, user=1728) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 157–158 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 167–168 | type: technical | tokens: in=2044 (sys=315, user=1729) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 167–168 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 169–170 | type: technical | tokens: in=1993 (sys=315, user=1678) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 169–170 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 171–172 | type: general | tokens: in=1836 (sys=299, user=1537) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 171–172 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 173–174 | type: technical | tokens: in=1057 (sys=315, user=742) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 173–174 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 175–176 | type: technical | tokens: in=1479 (sys=315, user=1164) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 165–166 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 177–178 | type: technical | tokens: in=880 (sys=315, user=565) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 175–176 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 179–180 | type: academic | tokens: in=1986 (sys=315, user=1671) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 179–180 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 181–182 | type: technical | tokens: in=2363 (sys=315, user=2048) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 177–178 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 183–184 | type: technical | tokens: in=1966 (sys=315, user=1651) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 183–184 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 185–186 | type: academic | tokens: in=1788 (sys=315, user=1473) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 181–182 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 187–188 | type: technical | tokens: in=938 (sys=315, user=623) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 185–186 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 189–190 | type: technical | tokens: in=1364 (sys=315, user=1049) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 189–190 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 191–192 | type: technical | tokens: in=1456 (sys=315, user=1141) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 191–192 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 193–194 | type: academic | tokens: in=1469 (sys=315, user=1154) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 187–188 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 195–196 | type: academic | tokens: in=1438 (sys=315, user=1123) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 193–194 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 197–198 | type: technical | tokens: in=762 (sys=315, user=447) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 195–196 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 199–200 | type: academic | tokens: in=2017 (sys=315, user=1702) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 197–198 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 201–202 | type: technical | tokens: in=1954 (sys=315, user=1639) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 201–202 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 203–204 | type: academic | tokens: in=1750 (sys=315, user=1435) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 203–204 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 205–206 | type: technical | tokens: in=1336 (sys=315, user=1021) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 199–200 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 207–208 | type: academic | tokens: in=1227 (sys=315, user=912) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 207–208 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 209–210 | type: legal | tokens: in=1068 (sys=314, user=754) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 209–210 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 211–212 | type: academic | tokens: in=1810 (sys=315, user=1495) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 205–206 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 213–214 | type: technical | tokens: in=1822 (sys=315, user=1507) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 211–212 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 215–216 | type: technical | tokens: in=1405 (sys=315, user=1090) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 213–214 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 217–218 | type: academic | tokens: in=1854 (sys=315, user=1539) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 215–216 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 219–220 | type: academic | tokens: in=1802 (sys=315, user=1487) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 219–220 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 221–222 | type: academic | tokens: in=1898 (sys=315, user=1583) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 221–222 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 223–224 | type: academic | tokens: in=1571 (sys=315, user=1256) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 223–224 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 225–226 | type: academic | tokens: in=1829 (sys=315, user=1514) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 217–218 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 227–228 | type: general | tokens: in=413 (sys=299, user=114) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 227–228 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 229–230 | type: technical | tokens: in=1725 (sys=315, user=1410) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 225–226 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 231–232 | type: academic | tokens: in=1562 (sys=315, user=1247) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 231–232 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 233–234 | type: academic | tokens: in=943 (sys=315, user=628) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 229–230 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 235–236 | type: technical | tokens: in=1384 (sys=315, user=1069) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 235–236 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 237–238 | type: technical | tokens: in=1001 (sys=315, user=686) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 237–238 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 239–240 | type: legal | tokens: in=1695 (sys=314, user=1381) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 239–240 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 241–242 | type: academic | tokens: in=1668 (sys=315, user=1353) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 233–234 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 243–243 | type: academic | tokens: in=603 (sys=315, user=288) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 241–242 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# ⚠️ 37_gcf-b39-02-add14-funding-proposal-package-fp239 | pages 243–243 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# ✅ Wrote lmstudio_output_md/chat-gpt/qwen_qwen3-coder-30b/37_gcf-b39-02-add14-funding-proposal-package-fp239.md
# 🏁 [1/273] Done 37_gcf-b39-02-add14-funding-proposal-package-fp239.pdf
#
# 🚀 [2/273] Start 209_gcf-b19-22-add08-rev01_0.pdf
#
# 📄 Processing PDF: 209_gcf-b19-22-add08-rev01_0.pdf
# 🔧 Split into 33 chunks (window=2)
# 🔢 209_gcf-b19-22-add08-rev01_0 | pages 1–2 | type: general | tokens: in=548 (sys=299, user=249) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# 🔢 209_gcf-b19-22-add08-rev01_0 | pages 3–4 | type: academic | tokens: in=1198 (sys=315, user=883) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 209_gcf-b19-22-add08-rev01_0 | pages 3–4 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 209_gcf-b19-22-add08-rev01_0 | pages 5–6 | type: technical | tokens: in=1061 (sys=315, user=746) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 209_gcf-b19-22-add08-rev01_0 | pages 5–6 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 209_gcf-b19-22-add08-rev01_0 | pages 7–8 | type: technical | tokens: in=1679 (sys=315, user=1364) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 209_gcf-b19-22-add08-rev01_0 | pages 7–8 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 209_gcf-b19-22-add08-rev01_0 | pages 9–10 | type: technical | tokens: in=1672 (sys=315, user=1357) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 209_gcf-b19-22-add08-rev01_0 | pages 1–2 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 209_gcf-b19-22-add08-rev01_0 | pages 11–12 | type: academic | tokens: in=2012 (sys=315, user=1697) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 209_gcf-b19-22-add08-rev01_0 | pages 9–10 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 209_gcf-b19-22-add08-rev01_0 | pages 13–14 | type: technical | tokens: in=1164 (sys=315, user=849) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 209_gcf-b19-22-add08-rev01_0 | pages 13–14 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 209_gcf-b19-22-add08-rev01_0 | pages 15–16 | type: technical | tokens: in=1849 (sys=315, user=1534) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 209_gcf-b19-22-add08-rev01_0 | pages 11–12 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# ...
# 🔢 155_gcf-b24-02-add06 | pages 169–170 | type: academic | tokens: in=2188 (sys=315, user=1873) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 155_gcf-b24-02-add06 | pages 163–164 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 155_gcf-b24-02-add06 | pages 171–172 | type: technical | tokens: in=2273 (sys=315, user=1958) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 155_gcf-b24-02-add06 | pages 169–170 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 155_gcf-b24-02-add06 | pages 173–174 | type: academic | tokens: in=1796 (sys=315, user=1481) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 155_gcf-b24-02-add06 | pages 173–174 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 155_gcf-b24-02-add06 | pages 175–176 | type: technical | tokens: in=2599 (sys=315, user=2284) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 155_gcf-b24-02-add06 | pages 175–176 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 155_gcf-b24-02-add06 | pages 177–178 | type: academic | tokens: in=1542 (sys=315, user=1227) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 155_gcf-b24-02-add06 | pages 177–178 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 155_gcf-b24-02-add06 | pages 179–180 | type: academic | tokens: in=2022 (sys=315, user=1707) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 155_gcf-b24-02-add06 | pages 171–172 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 155_gcf-b24-02-add06 | pages 181–182 | type: technical | tokens: in=1205 (sys=315, user=890) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 155_gcf-b24-02-add06 | pages 181–182 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 155_gcf-b24-02-add06 | pages 183–184 | type: academic | tokens: in=2071 (sys=315, user=1756) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 155_gcf-b24-02-add06 | pages 183–184 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 155_gcf-b24-02-add06 | pages 185–186 | type: academic | tokens: in=1602 (sys=315, user=1287) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 155_gcf-b24-02-add06 | pages 179–180 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 155_gcf-b24-02-add06 | pages 187–188 | type: technical | tokens: in=1438 (sys=315, user=1123) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 155_gcf-b24-02-add06 | pages 185–186 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 155_gcf-b24-02-add06 | pages 189–189 | type: technical | tokens: in=603 (sys=315, user=288) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 155_gcf-b24-02-add06 | pages 187–188 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# ⚠️ 155_gcf-b24-02-add06 | pages 189–189 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# ✅ Wrote lmstudio_output_md/chat-gpt/qwen_qwen3-coder-30b/155_gcf-b24-02-add06.md
# 🏁 [17/273] Done 155_gcf-b24-02-add06.pdf
#
# 🚀 [18/273] Start 39_gcf-b39-02-add12-rev01-funding-proposal-package-fp237.pdf
#
# 📄 Processing PDF: 39_gcf-b39-02-add12-rev01-funding-proposal-package-fp237.pdf
# 🔧 Split into 95 chunks (window=2)
# 🔢 39_gcf-b39-02-add12-rev01-funding-proposal-package-fp237 | pages 1–2 | type: technical | tokens: in=644 (sys=315, user=329) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# 🔢 39_gcf-b39-02-add12-rev01-funding-proposal-package-fp237 | pages 3–4 | type: general | tokens: in=785 (sys=299, user=486) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 39_gcf-b39-02-add12-rev01-funding-proposal-package-fp237 | pages 3–4 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 39_gcf-b39-02-add12-rev01-funding-proposal-package-fp237 | pages 5–6 | type: technical | tokens: in=825 (sys=315, user=510) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 39_gcf-b39-02-add12-rev01-funding-proposal-package-fp237 | pages 5–6 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 39_gcf-b39-02-add12-rev01-funding-proposal-package-fp237 | pages 7–8 | type: general | tokens: in=861 (sys=299, user=562) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 39_gcf-b39-02-add12-rev01-funding-proposal-package-fp237 | pages 1–2 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 39_gcf-b39-02-add12-rev01-funding-proposal-package-fp237 | pages 9–10 | type: academic | tokens: in=1612 (sys=315, user=1297) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 39_gcf-b39-02-add12-rev01-funding-proposal-package-fp237 | pages 7–8 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 39_gcf-b39-02-add12-rev01-funding-proposal-package-fp237 | pages 11–12 | type: academic | tokens: in=2166 (sys=315, user=1851) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 39_gcf-b39-02-add12-rev01-funding-proposal-package-fp237 | pages 9–10 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 39_gcf-b39-02-add12-rev01-funding-proposal-package-fp237 | pages 13–14 | type: academic | tokens: in=2118 (sys=315, user=1803) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 39_gcf-b39-02-add12-rev01-funding-proposal-package-fp237 | pages 13–14 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 39_gcf-b39-02-add12-rev01-funding-proposal-package-fp237 | pages 15–16 | type: technical | tokens: in=1543 (sys=315, user=1228) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ⚠️ 39_gcf-b39-02-add12-rev01-funding-proposal-package-fp237 | pages 11–12 failed: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
# 🔢 39_gcf-b39-02-add12-rev01-funding-proposal-package-fp237 | pages 17–18 | type: academic | tokens: in=1846 (sys=315, user=1531) | max_out=2048 | ctx=8192 | <TokenCounter mode=tiktoken:cl100k_base>
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File ~/Workspace/final_project_qna/venv/lib/python3.10/site-packages/aiohttp/connector.py:1268, in TCPConnector._wrap_create_connection(self, addr_infos, req, timeout, client_error, *args, **kwargs)
#    1265 async with ceil_timeout(
#    1266     timeout.sock_connect, ceil_threshold=timeout.ceil_threshold
#    1267 ):
# -> 1268     sock = await aiohappyeyeballs.start_connection(
#    1269         addr_infos=addr_infos,
#    1270         local_addr_infos=self._local_addr_infos,
#    1271         happy_eyeballs_delay=self._happy_eyeballs_delay,
#    1272         interleave=self._interleave,
#    1273         loop=self._loop,
#    1274         socket_factory=self._socket_factory,
#    1275     )
#    1276     # Add ssl_shutdown_timeout for Python 3.11+ when SSL is used
#
# File ~/Workspace/final_project_qna/venv/lib/python3.10/site-packages/aiohappyeyeballs/impl.py:122, in start_connection(addr_infos, local_addr_infos, happy_eyeballs_delay, interleave, loop, socket_factory)
#     121 if len(all_exceptions) == 1:
# --> 122     raise first_exception
#     123 else:
#     124     # If they all have the same str(), raise one.
#
# File ~/Workspace/final_project_qna/venv/lib/python3.10/site-packages/aiohappyeyeballs/impl.py:73, in start_connection(addr_infos, local_addr_infos, happy_eyeballs_delay, interleave, loop, socket_factory)
#      72 try:
# ---> 73     sock = await _connect_sock(
#      74         current_loop,
#      75         exceptions,
#      76         addrinfo,
#      77         local_addr_infos,
#      78         None,
#      79         socket_factory,
#      80     )
#      81     break
#
# File ~/Workspace/final_project_qna/venv/lib/python3.10/site-packages/aiohappyeyeballs/impl.py:208, in _connect_sock(loop, exceptions, addr_info, local_addr_infos, open_sockets, socket_factory)
#     207             raise OSError(f"no matching local address with {family=} found")
# --> 208 await loop.sock_connect(sock, address)
#     209 return sock
#
# File /usr/lib/python3.10/asyncio/selector_events.py:501, in BaseSelectorEventLoop.sock_connect(self, sock, address)
#     500 try:
# --> 501     return await fut
#     502 finally:
#     503     # Needed to break cycles when an exception occurs.
#
# File /usr/lib/python3.10/asyncio/selector_events.py:541, in BaseSelectorEventLoop._sock_connect_cb(self, fut, sock, address)
#     539     if err != 0:
#     540         # Jump to any except clause below.
# --> 541         raise OSError(err, f'Connect call failed {address}')
#     542 except (BlockingIOError, InterruptedError):
#     543     # socket is still registered, the callback will be retried later
#
# OSError: [Errno 113] Connect call failed ('192.168.10.60', 12345)
#
# The above exception was the direct cause of the following exception:
#
# ClientConnectorError                      Traceback (most recent call last)
# Cell In[1], line 230, in AsyncPDFProcessor._with_retries(self, coro_factory, tries, base, max_sleep)
#     229 try:
# --> 230     return await coro_factory()
#     231 except Exception as e:
#
# Cell In[1], line 260, in AsyncPDFProcessor.chat_markdownify(self, session, model, system_prompt, user_text, temperature, max_tokens)
#     259 url = f"{self.base_url}/chat/completions"
# --> 260 async with session.post(url, json=payload, headers=headers) as r:
#     261     if r.status != 200:
#
# File ~/Workspace/final_project_qna/venv/lib/python3.10/site-packages/aiohttp/client.py:1510, in _BaseRequestContextManager.__aenter__(self)
#    1509 async def __aenter__(self) -> _RetType:
# -> 1510     self._resp: _RetType = await self._coro
#    1511     return await self._resp.__aenter__()
#
# File ~/Workspace/final_project_qna/venv/lib/python3.10/site-packages/aiohttp/client.py:779, in ClientSession._request(self, method, str_or_url, params, data, json, cookies, headers, skip_auto_headers, auth, allow_redirects, max_redirects, compress, chunked, expect100, raise_for_status, read_until_eof, proxy, proxy_auth, timeout, verify_ssl, fingerprint, ssl_context, ssl, server_hostname, proxy_headers, trace_request_ctx, read_bufsize, auto_decompress, max_line_size, max_field_size, middlewares)
#     778 try:
# --> 779     resp = await handler(req)
#     780 # Client connector errors should not be retried
#
# File ~/Workspace/final_project_qna/venv/lib/python3.10/site-packages/aiohttp/client.py:734, in ClientSession._request.<locals>._connect_and_send_request(req)
#     733 try:
# --> 734     conn = await self._connector.connect(
#     735         req, traces=traces, timeout=real_timeout
#     736     )
#     737 except asyncio.TimeoutError as exc:
#
# File ~/Workspace/final_project_qna/venv/lib/python3.10/site-packages/aiohttp/connector.py:642, in BaseConnector.connect(self, req, traces, timeout)
#     641         await trace.send_connection_create_start()
# --> 642 proto = await self._create_connection(req, traces, timeout)
#     643 if traces:
#
# File ~/Workspace/final_project_qna/venv/lib/python3.10/site-packages/aiohttp/connector.py:1209, in TCPConnector._create_connection(self, req, traces, timeout)
#    1208 else:
# -> 1209     _, proto = await self._create_direct_connection(req, traces, timeout)
#    1211 return proto
#
# File ~/Workspace/final_project_qna/venv/lib/python3.10/site-packages/aiohttp/connector.py:1581, in TCPConnector._create_direct_connection(self, req, traces, timeout, client_error)
#    1580 assert last_exc is not None
# -> 1581 raise last_exc
#
# File ~/Workspace/final_project_qna/venv/lib/python3.10/site-packages/aiohttp/connector.py:1550, in TCPConnector._create_direct_connection(self, req, traces, timeout, client_error)
#    1549 try:
# -> 1550     transp, proto = await self._wrap_create_connection(
#    1551         self._factory,
#    1552         timeout=timeout,
#    1553         ssl=sslcontext,
#    1554         addr_infos=addr_infos,
#    1555         server_hostname=server_hostname,
#    1556         req=req,
#    1557         client_error=client_error,
#    1558     )
#    1559 except (ClientConnectorError, asyncio.TimeoutError) as exc:
#
# File ~/Workspace/final_project_qna/venv/lib/python3.10/site-packages/aiohttp/connector.py:1291, in TCPConnector._wrap_create_connection(self, addr_infos, req, timeout, client_error, *args, **kwargs)
#    1290     raise
# -> 1291 raise client_error(req.connection_key, exc) from exc
#
# ClientConnectorError: Cannot connect to host 192.168.10.60:12345 ssl:default [Connect call failed ('192.168.10.60', 12345)]
#
# During handling of the above exception, another exception occurred:
#
# CancelledError                            Traceback (most recent call last)
# Cell In[1], line 305, in AsyncPDFProcessor.process_one_chunk(self, session, semaphore, chunk)
#     298 print(
#     299     f"🔢 {chunk.pdf_name} | {chunk.page_range_label} | "
#     300     f"type: {doc_type} | "
#     301     f"tokens: in={in_toks} (sys={sys_toks}, user={usr_toks}) | "
#     302     f"max_out={max_out} | ctx={CONTEXT_WINDOW_TOKENS} | {self.tok}"
#     303 )
# --> 305 md = await self._with_retries(
#     306     lambda: self.chat_markdownify(
#     307         session,
#     308         MODEL,
#     309         system_prompt,
#     310         user_prompt,
#     311         temperature=TEMPERATURE,
#     312         max_tokens=int(max_out)
#     313     )
#     314 )
#     316 # --- POST-PROCESSING ---
#
# Cell In[1], line 237, in AsyncPDFProcessor._with_retries(self, coro_factory, tries, base, max_sleep)
#     236     sleep_for = min(max_sleep, base * (2 ** i)) + random.random()
# --> 237     await asyncio.sleep(sleep_for)
#     238 else:
#
# File /usr/lib/python3.10/asyncio/tasks.py:605, in sleep(delay, result)
#     604 try:
# --> 605     return await future
#     606 finally:
#
# CancelledError:
#
# During handling of the above exception, another exception occurred:
#
# CancelledError                            Traceback (most recent call last)
# Cell In[1], line 388
#     384     await processor.process_folder_sequential(FOLDER_PATH, OUTPUT_DIR)
#     387 if __name__ == "__main__":
# --> 388     await main_async()
#
# Cell In[1], line 384, in main_async()
#     382 async def main_async():
#     383     processor = AsyncPDFProcessor(LMSTUDIO_BASE_URL, api_key=LMSTUDIO_API_KEY or "")
# --> 384     await processor.process_folder_sequential(FOLDER_PATH, OUTPUT_DIR)
#
# Cell In[1], line 378, in AsyncPDFProcessor.process_folder_sequential(self, folder_path, output_dir)
#     376 for idx, pdf in enumerate(pdf_files, 1):
#     377     print(f"\n🚀 [{idx}/{len(pdf_files)}] Start {Path(pdf).name}")
# --> 378     await self.process_single_pdf(session, pdf, output_dir)
#     379     print(f"🏁 [{idx}/{len(pdf_files)}] Done {Path(pdf).name}")
#
# Cell In[1], line 351, in AsyncPDFProcessor.process_single_pdf(self, session, pdf_path, output_dir)
#     349 semaphore = asyncio.Semaphore(MAX_CONCURRENT)
#     350 tasks = [asyncio.create_task(self.process_one_chunk(session, semaphore, ch)) for ch in chunks]
# --> 351 results: List[Tuple[int, str]] = await asyncio.gather(*tasks)
#     353 results.sort(key=lambda x: x[0])
#     354 merged_md = "".join(md for _, md in results).strip() + "\n"
#
# CancelledError:

# %%
# !pip install -q pymupdf nest_asyncio

# %%
# Full replacement: use PyMuPDF (pymupdf / fitz) instead of pdfplumber.


import os
import asyncio
from concurrent.futures import ThreadPoolExecutor
import fitz  # PyMuPDF
import logging
import traceback
import nest_asyncio

# Enable nested event loop for Jupyter notebooks
nest_asyncio.apply()

# Logging
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger("pymupdf_extraction")

# --------- CONFIGURATION (edit these constants) ----------
PDF_SOURCE_DIR = "pdfs_20_2"        # relative to notebook cwd
OUTPUT_DIR = "pymupdf_output"       # relative to notebook cwd
MAX_WORKERS = 1                     # reduce if you run out of memory
OFFSET = 0                          # skip first N files
LIMIT = 273                         # 0 = all
EXTRACT_TABLES = True               # try to extract table-like CSV from pages
SEQUENTIAL = False                  # True => process one-by-one (lower mem)
# --------------------------------------------------------

def parse_and_save_pdf(pdf_path: str, out_path: str, extract_tables: bool = True) -> None:
    """
    Blocking worker: open pdf with PyMuPDF, collect metadata/pages and optional
    page-level CSV table extraction, then write a plain .txt file preserving basic structure.
    """
    try:
        parts = []
        doc = fitz.open(pdf_path)
        try:
            metadata = doc.metadata or {}
            if metadata:
                parts.append("=== DOCUMENT METADATA ===")
                for k, v in metadata.items():
                    if v is not None:
                        parts.append(f"{k}: {v}")
                parts.append("")

            for i, page in enumerate(doc, start=1):
                # Extract plain text (preserves newlines)
                try:
                    page_text = page.get_text("text") or ""
                except Exception:
                    page_text = ""
                if page_text.strip():
                    parts.append(f"=== PAGE {i} ===")
                    parts.append(page_text.strip())
                    parts.append("")

                # Try CSV extraction which can capture table-like structures
                if extract_tables:
                    try:
                        csv_text = page.get_text("csv") or ""
                    except Exception:
                        csv_text = ""
                    # csv_text often contains header/newlines only if table detected
                    if csv_text.strip():
                        parts.append(f"--- TABLES (csv) ON PAGE {i} ---")
                        # Split into lines and include as rows
                        for line in csv_text.splitlines():
                            parts.append(line.rstrip())
                        parts.append("")
        finally:
            doc.close()

        os.makedirs(os.path.dirname(out_path) or ".", exist_ok=True)
        with open(out_path, "w", encoding="utf-8") as f:
            f.write("\n".join(parts))

        logger.info("Saved: %s", out_path)

    except Exception as e:
        logger.exception("Failed to parse %s: %s\n%s", pdf_path, e, traceback.format_exc())


async def process_folder_async(
    src_folder: str,
    out_folder: str,
    max_workers: int = 2,
    offset: int = 0,
    limit: int = 0,
    extract_tables: bool = True,
    sequential: bool = False,
):
    # Validate folders
    if not os.path.isdir(src_folder):
        raise FileNotFoundError(f"Source folder does not exist: {src_folder}")
    os.makedirs(out_folder, exist_ok=True)

    files = [f for f in os.listdir(src_folder) if f.lower().endswith(".pdf")]
    files.sort()
    if limit > 0:
        files = files[offset: offset + limit]
    else:
        files = files[offset:]

    if not files:
        logger.info("No PDFs to process in %s", src_folder)
        return

    logger.info("Starting: %d files (offset=%d limit=%d) -> %s  sequential=%s workers=%d",
                len(files), offset, limit, out_folder, sequential, max_workers)

    loop = asyncio.get_event_loop()
    processed = 0
    failed = []

    if sequential:
        # Lower memory path: process one-by-one in same process/thread
        for fn in files:
            src = os.path.join(src_folder, fn)
            base = os.path.splitext(fn)[0]
            out_path = os.path.join(out_folder, f"{base}.txt")
            try:
                parse_and_save_pdf(src, out_path, extract_tables)
                processed += 1
                logger.info("✅ [%d/%d] %s", processed, len(files), fn)
            except Exception as e:
                failed.append((fn, str(e)))
                logger.error("❌ [%d/%d] %s -> %s", processed+1, len(files), fn, e)
    else:
        executor = ThreadPoolExecutor(max_workers=max_workers)
        semaphore = asyncio.Semaphore(max_workers)

        async def _worker(fn):
            async with semaphore:
                src = os.path.join(src_folder, fn)
                base = os.path.splitext(fn)[0]
                out_path = os.path.join(out_folder, f"{base}.txt")
                # run blocking parse_and_save_pdf in threadpool
                return await loop.run_in_executor(executor, parse_and_save_pdf, src, out_path, extract_tables)

        tasks = [asyncio.create_task(_worker(fn)) for fn in files]
        # gather with return_exceptions to let others finish if one fails
        results = await asyncio.gather(*tasks, return_exceptions=True)
        executor.shutdown(wait=True)

        for i, r in enumerate(results):
            fn = files[i]
            if isinstance(r, Exception):
                failed.append((fn, str(r)))
                logger.error("❌ [%d/%d] %s -> %s", i+1, len(files), fn, r)
            else:
                processed += 1
                logger.info("✅ [%d/%d] %s", processed, len(files), fn)

    logger.info("Done. Processed: %d  Failed: %d", processed, len(failed))
    if failed:
        logger.info("Failed files (sample 10): %s", failed[:10])


# ----------------- RUN (edit constants above instead of args) -----------------
# Build absolute paths relative to current working directory
cwd = os.getcwd()
src = os.path.join(cwd, PDF_SOURCE_DIR)
out = os.path.join(cwd, OUTPUT_DIR)

# Run in notebook with await
await process_folder_async(
    src_folder=src,
    out_folder=out,
    max_workers=MAX_WORKERS,
    offset=OFFSET,
    limit=LIMIT,
    extract_tables=EXTRACT_TABLES,
    sequential=SEQUENTIAL,
)
# Out:
# INFO:pymupdf_extraction:Starting: 273 files (offset=0 limit=273) -> /home/huncho/Workspace/final_project_qna/chat_interface/pymupdf_output  sequential=False workers=1
# INFO:pymupdf_extraction:Saved: /home/huncho/Workspace/final_project_qna/chat_interface/pymupdf_output/01_gcf-b42-02-add17-funding-proposal-package-fp275.txt
# INFO:pymupdf_extraction:Saved: /home/huncho/Workspace/final_project_qna/chat_interface/pymupdf_output/02_gcf-b42-02-add16-funding-proposal-package-fp274.txt
# INFO:pymupdf_extraction:Saved: /home/huncho/Workspace/final_project_qna/chat_interface/pymupdf_output/03_gcf-b42-02-add15-funding-proposal-package-fp273.txt
# INFO:pymupdf_extraction:Saved: /home/huncho/Workspace/final_project_qna/chat_interface/pymupdf_output/04_gcf-b42-02-add14-funding-proposal-package-fp272_0.txt
# INFO:pymupdf_extraction:Saved: /home/huncho/Workspace/final_project_qna/chat_interface/pymupdf_output/05_gcf-b42-02-add13-funding-proposal-package-fp271.txt
# INFO:pymupdf_extraction:Saved: /home/huncho/Workspace/final_project_qna/chat_interface/pymupdf_output/06_gcf-b42-02-add12-funding-proposal-package-fp270.txt
# INFO:pymupdf_extraction:Saved: /home/huncho/Workspace/final_project_qna/chat_interface/pymupdf_output/07_gcf-b42-02-add11-funding-proposal-package-fp269.txt
# INFO:pymupdf_extraction:Saved: /home/huncho/Workspace/final_project_qna/chat_interface/pymupdf_output/08_gcf-b42-02-add10-funding-proposal-package-fp268.txt
# INFO:pymupdf_extraction:Saved: /home/huncho/Workspace/final_project_qna/chat_interface/pymupdf_output/09_gcf-b42-02-add09-funding-proposal-package-fp267.txt
# INFO:pymupdf_extraction:Saved: /home/huncho/Workspace/final_project_qna/chat_interface/pymupdf_output/100_gcf-b30-02-add07.txt
# INFO:pymupdf_extraction:Saved: /home/huncho/Workspace/final_project_qna/chat_interface/pymupdf_output/101_gcf-b30-02-add06.txt
# INFO:pymupdf_extraction:Saved: /home/huncho/Workspace/final_project_qna/chat_interface/pymupdf_output/102_gcf-b30-02-add05.txt
# INFO:pymupdf_extraction:Saved: /home/huncho/Workspace/final_project_qna/chat_interface/pymupdf_output/103_gcf-b30-03-add04.txt
# INFO:pymupdf_extraction:Saved: /home/huncho/Workspace/final_project_qna/chat_interface/pymupdf_output/104_gcf-b30-03-add03.txt
# INFO:pymupdf_extraction:Saved: /home/huncho/Workspace/final_project_qna/chat_interface/pymupdf_output/105_gcf-b30-02-add02.txt
# INFO:pymupdf_extraction:Saved: /home/huncho/Workspace/final_project_qna/chat_interface/pymupdf_output/106_gcf-b30-02-add01.txt
# INFO:pymupdf_extraction:Saved: /home/huncho/Workspace/final_project_qna/chat_interface/pymupdf_output/107_gcf-b29-02-add04.txt
# INFO:pymupdf_extraction:Saved: /home/huncho/Workspace/final_project_qna/chat_interface/pymupdf_output/108_gcf-b29-02-add03-rev02.txt
# INFO:pymupdf_extraction:Saved: /home/huncho/Workspace/final_project_qna/chat_interface/pymupdf_output/109_gcf-b29-02-add02.txt
# INFO:pymupdf_extraction:Saved: /home/huncho/Workspace/final_project_qna/chat_interface/pymupdf_output/10_gcf-b42-02-add08-funding-proposal-package-fp266.txt
# INFO:pymupdf_extraction:Saved: /home/huncho/Workspace/final_project_qna/chat_interface/pymupdf_output/110_gcf-b29-02-add01.txt
# INFO:pymupdf_extraction:Saved: /home/huncho/Workspace/final_project_qna/chat_interface/pymupdf_output/111_gcf-b28-02-add11.txt
# INFO:pymupdf_extraction:Saved: /home/huncho/Workspace/final_project_qna/chat_interface/pymupdf_output/112_gcf-b28-02-add10.txt
# INFO:pymupdf_extraction:Saved: /home/huncho/Workspace/final_project_qna/chat_interface/pymupdf_output/113_gcf-b28-02-add09.txt
# INFO:pymupdf_extraction:Saved: /home/huncho/Workspace/final_project_qna/chat_interface/pymupdf_output/114_gcf-b28-02-add08.txt
# INFO:pymupdf_extraction:Saved: /home/huncho/Workspace/final_project_qna/chat_interface/pymupdf_output/115_gcf-b28-02-add07-rev01.txt
# INFO:pymupdf_extraction:Saved: /home/huncho/Workspace/final_project_qna/chat_interface/pymupdf_output/116_gcf-b28-02-add06.txt
# INFO:pymupdf_extraction:Saved: /home/huncho/Workspace/final_project_qna/chat_interface/pymupdf_output/117_gcf-b28-02-add05.txt
# INFO:pymupdf_extraction:Saved: /home/huncho/Workspace/final_project_qna/chat_interface/pymupdf_output/118_gcf-b28-02-add04.txt
# INFO:pymupdf_extraction:Saved: /home/huncho/Workspace/final_project_qna/chat_interface/pymupdf_output/119_gcf-b28-02-add03-rev01.txt
# INFO:pymupdf_extraction:Saved: /home/huncho/Workspace/final_project_qna/chat_interface/pymupdf_output/11_gcf-b42-02-add07-funding-proposal-package-fp265.txt
# INFO:pymupdf_extraction:Saved: /home/huncho/Workspace/final_project_qna/chat_interface/pymupdf_output